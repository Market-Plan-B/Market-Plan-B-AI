# %%
import pandas as pd

# %%
eco=pd.read_csv("../data/ecos_key_statistics.csv")
eco.head()
# Out:
#   CLASS_NAME   KEYSTAT_NAME  DATA_VALUE     CYCLE UNIT_NAME
# 0       시장금리      한국은행 기준금리        2.50  20251102         %
# 1       시장금리       콜금리(익일물)        2.43  20251104         %
# 2       시장금리   KORIBOR(3개월)        2.60  20251104         %
# 3       시장금리     CD수익률(91일)        2.57  20251104         %
# 4       시장금리  통안증권수익률(364일)        2.42  20251104         %
